# %%
import pandas as pd

# %%
pd.read_csv("/content/Assignment-1_Data.csv",sep = ";")
# Out:
#         BillNo                             Itemname  Quantity  \
# 0       536365   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1       536365                  WHITE METAL LANTERN       6.0
# 2       536365       CREAM CUPID HEARTS COAT HANGER       8.0
# 3       536365  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4       536365       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...        ...                                  ...       ...
# 133454  548194       PIG KEYRING WITH LIGHT & SOUND       1.0
# 133455  548194       COFFEE MUG BLUE PAISLEY DESIGN       1.0
# 133456  548194       OFFICE MUG WARMER BLACK+SILVER       1.0
# 133457  548194        BIRD DECORATION RED RETROSPOT       4.0
# 133458  548194               ROUND SNACK BOXES SET        NaN
#
#                     Date Price  CustomerID         Country
# 0       01.12.2010 08:26  2,55     17850.0  United Kingdom
# 1       01.12.2010 08:26  3,39     17850.0  United Kingdom
# ...

# %%
data = pd.read_csv("/content/Assignment-1_Data.csv",sep = ";")

# %%
data.head()
# Out:
#    BillNo                             Itemname  Quantity              Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
#
#   Price  CustomerID         Country
# 0  2,55     17850.0  United Kingdom
# 1  3,39     17850.0  United Kingdom
# 2  2,75     17850.0  United Kingdom
# 3  3,39     17850.0  United Kingdom
# 4  3,39     17850.0  United Kingdom

# %%
#R#which product was recently bought?
#F# Which product the custoemr have frequently bought? - Different asumptions for one questions
#R#which product was recently bought?

# %%
data_col = pd.DatetimeIndex(data["Date"])

# %%
data['Years'] = data_col.year
data['Month'] = data_col.month
data['Day'] = data_col.day

# %%
#R#which product was recently bought?
data.groupby(["Itemname","Date","CustomerID"])["Quantity"].value_counts()
# Out:
# Itemname                          Date              CustomerID  Quantity
# 10 COLOUR SPACEBOY PEN            01.12.2010 11:41  14307.0     24          1
#                                   01.12.2010 13:38  15605.0     24          1
#                                   01.12.2010 15:00  13093.0     96          1
#                                   02.02.2011 17:06  17337.0     12          1
#                                   02.12.2010 10:17  17017.0     24          1
#                                                                            ..
# ZINC WILLIE WINKIE  CANDLE STICK  27.03.2011 16:05  15426.0     4           1
#                                   28.01.2011 11:58  16327.0     24          1
#                                   28.02.2011 14:03  17027.0     1           2
#                                   30.03.2011 09:19  15674.0     12          1
#                                   31.01.2011 11:46  12476.0     24          1
# ...

# %%
data["Date"].min()
# Out:
# '01.02.2011 08:23'

# %%
data["Date"].max()
# Out:
# '31.03.2011 19:55'

# %%
#F# Which product the custoemr have frequently bought? - Different asumptions for one questions
data.loc[data.groupby(["Itemname"])["Quantity"].transform(max).idxmax()][["Itemname","Quantity"]]
# Out:
# Itemname    MEDIUM CERAMIC TOP STORAGE JAR
# Quantity                             74215
# Name: 59999, dtype: object

# %%
#S# what us the total amount spent on each and every product?
#data.insert(7,"Totalprice",0)
data
# Out:
#         BillNo                             Itemname  Quantity  \
# 0       536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365                  WHITE METAL LANTERN         6
# 2       536365       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...                                  ...       ...
# 160055  550833            MEMO BOARD COTTAGE DESIGN         2
# 160056  550834             REGENCY CAKESTAND 3 TIER         1
# 160057  550834     PACK OF 20 NAPKINS PANTRY DESIGN         3
# 160058  550834          PINK HAPPY BIRTHDAY BUNTING         1
# 160059  550834         REX CASH+CARRY JUMBO SHOPPER         1
#
#                     Date  Price  CustomerID         Country  Totalprice  \
# 0       01.12.2010 08:26   2,55     17850.0  United Kingdom           0
# 1       01.12.2010 08:26   3,39     17850.0  United Kingdom           0
# ...

# %%
data["Totalprice"] = data["Quantity"]*data["Price"]

# %%
data.groupby(["Itemname","Totalprice"])["Quantity"].count().reset_index()
# Out:
#                            Itemname  \
# 0             *Boombox Ipod Classic
# 1           *USB Office Mirror Ball
# 2            10 COLOUR SPACEBOY PEN
# 3            10 COLOUR SPACEBOY PEN
# 4            10 COLOUR SPACEBOY PEN
# ...                             ...
# 35338                 wrong barcode
# 35339         wrong barcode (22467)
# 35340  wrongly sold (22719) barcode
# 35341          wrongly sold as sets
# 35342             wrongly sold sets
#
#                                               Totalprice  Quantity
# 0                                                  16,98         1
# 1                                                   8,47         2
# 2                                                   0,85         2
# 3                                               0,850,85         4
# 4                                   0,850,850,850,850,85         1
# ...                                                  ...       ...
# ...

# %%
data.groupby(["Itemname","Totalprice","CustomerID"])["Quantity"].count().reset_index()
# Out:
#                                Itemname  \
# 0                10 COLOUR SPACEBOY PEN
# 1                10 COLOUR SPACEBOY PEN
# 2                10 COLOUR SPACEBOY PEN
# 3                10 COLOUR SPACEBOY PEN
# 4                10 COLOUR SPACEBOY PEN
# ...                                 ...
# 99138  ZINC WILLIE WINKIE  CANDLE STICK
# 99139  ZINC WILLIE WINKIE  CANDLE STICK
# 99140  ZINC WILLIE WINKIE  CANDLE STICK
# 99141  ZINC WILLIE WINKIE  CANDLE STICK
# 99142  ZINC WILLIE WINKIE  CANDLE STICK
#
#                                               Totalprice  CustomerID  Quantity
# 0                                                   0,85     17585.0         1
# 1                                                   0,85     17961.0         1
# 2                                               0,850,85     14390.0         1
# 3                                               0,850,85     14396.0         1
# 4                                               0,850,85     17341.0         1
# ...

# %%
#how many times a customer has purchased a specific product?
data.query("CustomerID in [17850] & Itemname in['WHITE METAL LANTERN']")[['Itemname','CustomerID']]
# Out:
#                  Itemname  CustomerID
# 1     WHITE METAL LANTERN     17850.0
# 50    WHITE METAL LANTERN     17850.0
# 67    WHITE METAL LANTERN     17850.0
# 270   WHITE METAL LANTERN     17850.0
# 408   WHITE METAL LANTERN     17850.0
# 3072  WHITE METAL LANTERN     17850.0
# 3096  WHITE METAL LANTERN     17850.0
# 3145  WHITE METAL LANTERN     17850.0
# 3177  WHITE METAL LANTERN     17850.0
# 3376  WHITE METAL LANTERN     17850.0
# 3394  WHITE METAL LANTERN     17850.0
# 3758  WHITE METAL LANTERN     17850.0
# 3773  WHITE METAL LANTERN     17850.0
# 4108  WHITE METAL LANTERN     17850.0
# 4129  WHITE METAL LANTERN     17850.0
# 4453  WHITE METAL LANTERN     17850.0
# 4469  WHITE METAL LANTERN     17850.0

# %%
#how many times a customer has purchased a specific product?
#data.query("*USB Office Mirror Ball in ['Itemname'] & CustomerID in['17850.0']")[['Itemname','CustomerID']]
data.query("CustomerID	 in[17850] & Itemname in ['WHITE METAL LANTERN']")[['Itemname','CustomerID']]
#data.query("CustomerID in [10750] & Itemname in ['WHITE METAL LANTERN']")
# Out:
#                  Itemname  CustomerID
# 1     WHITE METAL LANTERN     17850.0
# 50    WHITE METAL LANTERN     17850.0
# 67    WHITE METAL LANTERN     17850.0
# 270   WHITE METAL LANTERN     17850.0
# 408   WHITE METAL LANTERN     17850.0
# 3072  WHITE METAL LANTERN     17850.0
# 3096  WHITE METAL LANTERN     17850.0
# 3145  WHITE METAL LANTERN     17850.0
# 3177  WHITE METAL LANTERN     17850.0
# 3376  WHITE METAL LANTERN     17850.0
# 3394  WHITE METAL LANTERN     17850.0
# 3758  WHITE METAL LANTERN     17850.0
# 3773  WHITE METAL LANTERN     17850.0
# 4108  WHITE METAL LANTERN     17850.0
# 4129  WHITE METAL LANTERN     17850.0
# 4453  WHITE METAL LANTERN     17850.0
# 4469  WHITE METAL LANTERN     17850.0

# %%
#What is the average purchase amount per customer?
data.groupby(['Itemname','Price','CustomerID'])['Quantity'].mean().reset_index()
# Out:
#                                Itemname Price  CustomerID  Quantity
# 0                10 COLOUR SPACEBOY PEN  0,85     12413.0      24.0
# 1                10 COLOUR SPACEBOY PEN  0,85     12456.0      24.0
# 2                10 COLOUR SPACEBOY PEN  0,85     12520.0      24.0
# 3                10 COLOUR SPACEBOY PEN  0,85     12553.0      24.0
# 4                10 COLOUR SPACEBOY PEN  0,85     12567.0      24.0
# ...                                 ...   ...         ...       ...
# 90290  ZINC WILLIE WINKIE  CANDLE STICK  0,85     17576.0       1.0
# 90291  ZINC WILLIE WINKIE  CANDLE STICK  0,85     17613.0      12.0
# 90292  ZINC WILLIE WINKIE  CANDLE STICK  0,85     17672.0      24.0
# 90293  ZINC WILLIE WINKIE  CANDLE STICK  0,85     17961.0       4.0
# 90294  ZINC WILLIE WINKIE  CANDLE STICK  0,85     18069.0       4.0
#
# [90295 rows x 4 columns]

# %%
data.head()
# Out:
#    BillNo                             Itemname  Quantity              Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
#
#   Price  CustomerID         Country                        Totalprice  Years  \
# 0  2,55     17850.0  United Kingdom          2,552,552,552,552,552,55   2010
# 1  3,39     17850.0  United Kingdom          3,393,393,393,393,393,39   2010
# 2  2,75     17850.0  United Kingdom  2,752,752,752,752,752,752,752,75   2010
# 3  3,39     17850.0  United Kingdom          3,393,393,393,393,393,39   2010
# 4  3,39     17850.0  United Kingdom          3,393,393,393,393,393,39   2010
#
#    Month  Day
# 0      1   12
# 1      1   12
# ...
